// %%
#include <blaze/Math.h>
#include <numeric>

// %%
size_t N = 100;
auto x = blaze::DynamicVector<double>(N,0);
for(size_t i = 0 ; i < N  ; i++)
    x[i] = i*0.1;

// %%
// Passing C++ vectors to Python arrays

// %%
%data x
// Out:
// x shape is (100,)

// %%
%%plot
import numpy as np
plt.xlabel("x-Label")
plt.ylabel("y-label")
plt.plot(x,np.sin(x),label="Data")
plt.grid()
plt.legend()
// Out:
// <pre>
// </pre><img src='data:image/png;base64,...' />
